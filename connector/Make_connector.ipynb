# %% [markdown]
# The goal is to create connector between clinical data and rtstruct data, by creating cinsistances between the clinical lesion names and the rtstruct lesion names.

# %% [markdown]
# Since majority of the work is done by hand you can jump right to the last cells

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# In this part i am retrieving the way i created the file names. inorder to find a column how to merge join the file names with the clinical data

# %%
#read the metadata
df = pd.read_csv("../data/metadata.csv")

# %%
import SimpleITK as sitk
import pydicom
import glob
import os
from rt_utils import RTStructBuilder
import re

grouped_df = df.groupby(['pid', 'Study Date'])

rt_lesions = pd.DataFrame(columns=['sid', 'date', 'lesion', 'lesion_clean', 'course','file_name','sex','height','weight','age']) 

# Iterate over each group
for group_name, group_data in grouped_df:
    # Get the 'SOP Class Name' and 'File Location' for each group
    folders_dic = dict(zip(group_data['SOP Class Name'], group_data['File Location']))
    
    mri_folder = os.path.join('../data',folders_dic['MR Image Storage'])
    str_folder = os.path.join('../data',folders_dic['RT Structure Set Storage'])

    # STRUCT
    str_file = glob.glob(os.path.join(str_folder, "*.dcm"))[0]   
    rtstruct = RTStructBuilder.create_from(dicom_series_path=mri_folder,rt_struct_path=str_file)
    names = rtstruct.get_roi_names()
    lesions = [name for name in names if "Skull" not in name] 

    try:
        sex = rtstruct.ds.PatientSex
    except AttributeError:
        sex = 'NA'

    try:
        height = np.round(rtstruct.ds.PatientSize, 2)
    except (AttributeError, TypeError):
        height = -1.0

    try:
        weight = int(rtstruct.ds.PatientWeight)
    except (AttributeError, ValueError):
        weight = -1

    try:
        age = int(''.join(re.findall(r'\d+', rtstruct.ds.PatientAge)))
    except (AttributeError, ValueError):
        age = -1

    for lesion in lesions:
        
        #build a dataframe
        sid, date = group_name
        course = int(group_data[group_data.Modality == 'RTSTRUCT']['Series Description'].values[0][-1])
        lesion_clean = re.sub('[^A-Za-z]+', '', lesion)
        file_name=f"{sid}_{course}_{lesion_clean}"  
        new_row = [sid, date, lesion, lesion_clean,course,file_name,sex,height,weight,age]
        rt_lesions.loc[len(rt_lesions)] = new_row

# %% [markdown]
# rt_lesion contain all the lesions that are present in the RT STRUCT with the original lesion names

# %%
rt_lesions.head()
# Out:
#    sid        date            lesion    lesion_clean  course  \
# 0  103  04-18-2014          R atrium         Ratrium       1
# 1  103  04-18-2014        L temporal       Ltemporal       1
# 2  103  12-18-2014        Rt Frontal       RtFrontal       2
# 3  103  12-18-2014    Rt Sup Frontal    RtSupFrontal       2
# 4  103  12-18-2014  R Inf Cerebellar  RInfCerebellar       2
#
#               file_name sex  height  weight  age
# 0         103_1_Ratrium   F    1.65      75   78
# 1       103_1_Ltemporal   F    1.65      75   78
# 2       103_2_RtFrontal   F   -1.00      -1   79
# 3    103_2_RtSupFrontal   F   -1.00      -1   79
# 4  103_2_RInfCerebellar   F   -1.00      -1   79

# %%
rt_lesions.to_csv('rt_lesions.csv', index=False)

# %% [markdown]
# Create the clinical data

# %%
import pandas as pd
import os

# Read the Excel file
excel_file = pd.ExcelFile('../data/Brain-TR-GammaKnife Clinical Information.xlsx')

# Get the sheet names
sheet_names = excel_file.sheet_names

# Read each sheet into a DataFrame
dfs = {}
for sheet_name in sheet_names:
    dfs[sheet_name] = excel_file.parse(sheet_name)

# Access the DataFrame for a specific sheet
df_cl = dfs['course_level']
df_ll = dfs['lesion_level']
df_ll = df_ll.drop('No.', axis=1)
df_cl = df_cl.rename(columns={'Course #': 'course'})
df_ll = df_ll.rename(columns={'Treatment Course': 'course'})
df_ll = df_ll.rename(columns={'Lesion Location': 'lesion'})
df_ll = df_ll.rename(columns={'unique_pt_id': 'sid'})
df_cl = df_cl.rename(columns={'unique_pt_id': 'sid'})

clinical = df_cl.merge(df_ll, on=['sid', 'course'], how='right')
clinical = clinical.drop(['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Lesion Name in NRRD files'], axis=1) #, 'unique_pt_id'

# %%
clinical
clinical.to_csv('clinical_data.csv', index=False)

# %% [markdown]
# join clinincal with rt_lesions on lesion

# %%
jdf=clinical.merge(rt_lesions, on=['lesion','sid','course'], how='outer', indicator=True)

# %% [markdown]
# **At this point I wrked by hand to create the connctor**

# %% [markdown]
# I have asked chatgpt to exend the left and right

# %%
c = pd.read_csv('clinical_data_camel_chat_gpt.csv')
s = pd.read_csv('rt_lesions_camel_chat_gpt.csv')

# %%
c.head()
# Out:
#    sid  course Diagnosis (Only want Mets)           Primary Diagnosis  \
# 0  463       1           Brain Mets-Lung   Adenocarcinoma of the lung
# 1  463       2           Brain Mets-Lung   Adenocarcinoma of the lung
# 2  463       2           Brain Mets-Lung   Adenocarcinoma of the lung
# 3  463       2           Brain Mets-Lung   Adenocarcinoma of the lung
# 4  158       1          Brain Mets -Lung   Adenocarcinoma of the lung
#
#    Age at Diagnosis Gender  Lesion #             lesion    mri_type  \
# 0                60   Male         1         Lt Frontal  recurrence
# 1                60   Male         2     R Motor Cortex      stable
# 2                60   Male         3   Lt Post Temporal      stable
# 3                60   Male         4  Lt Lat Cerebellum      stable
# 4                58   Male         1     Rt SUP Frontal      stable
#
#    duration_tx_to_imag (months)  Fractions             chat_gpt
# 0                     10.713112          1         Left Frontal
# 1                      7.952678          1   Right Motor Cortex
# 2                      7.952678          1   Left Post Temporal
# 3                      7.952678          1  Left Lat Cerebellum
# 4                      1.774565          1    Right Sup Frontal

# %%
s.head()
# Out:
#    sid        date            lesion    lesion_clean  course  \
# 0  103  04-18-2014          R atrium         Ratrium       1
# 1  103  04-18-2014        L temporal       Ltemporal       1
# 2  103  12-18-2014        Rt Frontal       RtFrontal       2
# 3  103  12-18-2014    Rt Sup Frontal    RtSupFrontal       2
# 4  103  12-18-2014  R Inf Cerebellar  RInfCerebellar       2
#
#               file_name              chat_gpt
# 0         103_1_Ratrium          Right Atrium
# 1       103_1_Ltemporal         Left Temporal
# 2       103_2_RtFrontal         Right Frontal
# 3    103_2_RtSupFrontal     Right Sup Frontal
# 4  103_2_RInfCerebellar  Right Inf Cerebellar

# %%
jdf=c.merge(s, on=['chat_gpt','sid','course'], how='outer', indicator=True)

# %%
jdf.to_csv('rt_lesions_camel_chat_gpt.csv', index=False)

# %% [markdown]
# !!!!! THe following file, holds the final hand work !!!!! You can start from here to create the connector !!!!!

# %%
jdf=pd.read_csv('rt_lesions_camel_chat_gpt_corrected.csv')
jdf
# Out:
#      sid  course Diagnosis (Only want Mets)           Primary Diagnosis  \
# 0    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 1    151       1                        NaN                         NaN
# 2    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 3    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 4    151       1                        NaN                         NaN
# ..   ...     ...                        ...                         ...
# 339  492       2          Brain Mets - Lung  Adenocarcinoma of the lung
# 340  246       1           Brain Mets-Lung   Adenocarcinoma of the lung
# 341  246       1                        NaN                         NaN
# 342  257       3      Brain Mets Renal cell        Renal cell carcinoma
# 343  257       3      Brain Mets Renal cell        Renal cell carcinoma
#
#      Age at Diagnosis  Gender  Lesion #              lesion_x mri_type  \
# 0                77.0  Female       1.0  1 Lt Inf Cerebellar1   stable
# 1                 NaN     NaN       NaN                   NaN      NaN
# 2                77.0  Female      10.0  10 Lt Ant Frontal 1    stable
# 3                77.0  Female      11.0       11 Lt Med Ant 1   stable
# 4                 NaN     NaN       NaN                   NaN      NaN
# ..                ...     ...       ...                   ...      ...
# 339              73.0    Male      13.0           Rt temporal   stable
# 340              62.0  Female       4.0            Rt Thalmic   stable
# 341               NaN     NaN       NaN                   NaN      NaN
# 342              58.0  Female      13.0          Rt Ventricle   stable
# 343              58.0  Female      15.0                Vermis   stable
#
#      duration_tx_to_imag (months)  Fractions                   chat_gpt  \
# 0                       42.458101        1.0     1 Left Inf Cerebellar1
# 1                             NaN        NaN    1 Left Inf Cerebellar 1
# 2                       42.458101        1.0      10 Left Ant Frontal 1
# 3                       42.458101        1.0          11 Left Med Ant 1
# 4                             NaN        NaN  11 Left Med Ant Frontal 1
# ..                            ...        ...                        ...
# 339                     11.501807        1.0             Right Temporal
# 340                      0.854420        1.0              Right Thalmic
# 341                           NaN        NaN         4 Right Thalamic 1
# 342                     41.307920        1.0            Right Ventricle
# 343                     41.307920        1.0                     Vermis
#
#                              to_change      _merge        date  \
# 0         1 Left Inferior Cerebellar 1   left_only         NaN
# 1         1 Left Inferior Cerebellar 1  right_only  10-31-2013
# 2           10 Left Anterior Frontal 1        both  10-31-2013
# 3    11 Left Medial Anterior Frontal 1   left_only         NaN
# 4    11 Left Medial Anterior Frontal 1  right_only  10-31-2013
# ..                                 ...         ...         ...
# 339                     Right Temporal        both  12-11-2014
# 340                     Right Thalamic   left_only         NaN
# 341                     Right Thalamic  right_only  07-10-2013
# 342                    Right Ventricle        both  09-29-2014
# 343                             Vermis        both  09-29-2014
#
#                     lesion_y     lesion_clean              file_name
# 0                        NaN              NaN                    NaN
# 1      1 Lt Inf Cerebellar 1  LtInfCerebellar  151_1_LtInfCerebellar
# 2        10 Lt ant Frontal 1     LtantFrontal     151_1_LtantFrontal
# 3                        NaN              NaN                    NaN
# 4    11 Lt med ant frontal 1  Ltmedantfrontal  151_1_Ltmedantfrontal
# ..                       ...              ...                    ...
# 339               R temporal        Rtemporal        492_2_Rtemporal
# 340                      NaN              NaN                    NaN
# 341          4 Rt Thalamic 1       RtThalamic       246_1_RtThalamic
# 342             Rt Ventricle      RtVentricle      257_3_RtVentricle
# 343                   Vermis           Vermis           257_3_Vermis
#
# [344 rows x 18 columns]

# %%
cc=jdf[(jdf._merge=="both") | (jdf._merge=="left_only")].drop('_merge', axis=1).dropna(axis=1).reset_index(drop=True).rename(columns={'lesion_x': 'lesion'})
sc=jdf[(jdf._merge=="both") | (jdf._merge=="right_only")].drop('_merge', axis=1).dropna(axis=1).reset_index(drop=True).rename(columns={'lesion_y': 'lesion'})

# %%
# (cc['sid'].value_counts()-jdfc['sid'].value_counts()).sort_values(ascending=False).head(10)

# %%
cc
# Out:
#      sid  course Diagnosis (Only want Mets)           Primary Diagnosis  \
# 0    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 1    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 2    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 3    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 4    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# ..   ...     ...                        ...                         ...
# 239  105       1          Brain Mets Kidney     Squamous cell carcinoma
# 240  492       2          Brain Mets - Lung  Adenocarcinoma of the lung
# 241  246       1           Brain Mets-Lung   Adenocarcinoma of the lung
# 242  257       3      Brain Mets Renal cell        Renal cell carcinoma
# 243  257       3      Brain Mets Renal cell        Renal cell carcinoma
#
#      Age at Diagnosis  Gender  Lesion #                lesion mri_type  \
# 0                77.0  Female       1.0  1 Lt Inf Cerebellar1   stable
# 1                77.0  Female      10.0  10 Lt Ant Frontal 1    stable
# 2                77.0  Female      11.0       11 Lt Med Ant 1   stable
# 3                77.0  Female      12.0   12 Rt Ant Frontal 1   stable
# 4                77.0  Female      13.0        13 Lt Vertex 1   stable
# ..                ...     ...       ...                   ...      ...
# 239              58.0    Male       1.0           RT Temporal   stable
# 240              73.0    Male      13.0           Rt temporal   stable
# 241              62.0  Female       4.0            Rt Thalmic   stable
# 242              58.0  Female      13.0          Rt Ventricle   stable
# 243              58.0  Female      15.0                Vermis   stable
#
#      duration_tx_to_imag (months)  Fractions                chat_gpt  \
# 0                       42.458101        1.0  1 Left Inf Cerebellar1
# 1                       42.458101        1.0   10 Left Ant Frontal 1
# 2                       42.458101        1.0       11 Left Med Ant 1
# 3                       42.458101        1.0  12 Right Ant Frontal 1
# 4                       42.458101        1.0        13 Left Vertex 1
# ..                            ...        ...                     ...
# 239                      2.103188        1.0          Right Temporal
# 240                     11.501807        1.0          Right Temporal
# 241                      0.854420        1.0           Right Thalmic
# 242                     41.307920        1.0         Right Ventricle
# 243                     41.307920        1.0                  Vermis
#
#                              to_change
# 0         1 Left Inferior Cerebellar 1
# 1           10 Left Anterior Frontal 1
# 2    11 Left Medial Anterior Frontal 1
# 3          12 Right Anterior Frontal 1
# 4                     13 Left Vertex 1
# ..                                 ...
# 239                     Right Temporal
# 240                     Right Temporal
# 241                     Right Thalamic
# 242                    Right Ventricle
# 243                             Vermis
#
# [244 rows x 13 columns]

# %%
sc
# Out:
#      sid  course                   chat_gpt  \
# 0    151       1    1 Left Inf Cerebellar 1
# 1    151       1      10 Left Ant Frontal 1
# 2    151       1  11 Left Med Ant Frontal 1
# 3    151       1     12 Right Ant Frontal 1
# 4    151       1             13 Left Vertex
# ..   ...     ...                        ...
# 244  105       1             Right Temporal
# 245  492       2             Right Temporal
# 246  246       1         4 Right Thalamic 1
# 247  257       3            Right Ventricle
# 248  257       3                     Vermis
#
#                              to_change        date                   lesion  \
# 0         1 Left Inferior Cerebellar 1  10-31-2013    1 Lt Inf Cerebellar 1
# 1           10 Left Anterior Frontal 1  10-31-2013      10 Lt ant Frontal 1
# 2    11 Left Medial Anterior Frontal 1  10-31-2013  11 Lt med ant frontal 1
# 3          12 Right Anterior Frontal 1  10-31-2013      12 Rt ant frontal 1
# 4                     13 Left Vertex 1  10-31-2013             13 Lt vertex
# ..                                 ...         ...                      ...
# 244                     Right Temporal  09-04-2014              RT Temporal
# 245                     Right Temporal  12-11-2014               R temporal
# 246                     Right Thalamic  07-10-2013          4 Rt Thalamic 1
# 247                    Right Ventricle  09-29-2014             Rt Ventricle
# 248                             Vermis  09-29-2014                   Vermis
#
#         lesion_clean              file_name
# 0    LtInfCerebellar  151_1_LtInfCerebellar
# 1       LtantFrontal     151_1_LtantFrontal
# 2    Ltmedantfrontal  151_1_Ltmedantfrontal
# 3       Rtantfrontal     151_1_Rtantfrontal
# 4           Ltvertex         151_1_Ltvertex
# ..               ...                    ...
# 244       RTTemporal       105_1_RTTemporal
# 245        Rtemporal        492_2_Rtemporal
# 246       RtThalamic       246_1_RtThalamic
# 247      RtVentricle      257_3_RtVentricle
# 248           Vermis           257_3_Vermis
#
# [249 rows x 8 columns]

# %%
jdfc=cc.merge(sc, on=['to_change','sid','course'], how='inner', indicator=True)

# %%
jdfc=jdfc.rename(columns={'lesion_x': 'lesion_clinical', 'lesion_y': 'lesion_rtstruct','to_change': 'lesion'}).drop(['_merge','chat_gpt_x','chat_gpt_y'], axis=1).dropna(axis=1).reset_index(drop=True)
jdfc
# Out:
#      sid  course Diagnosis (Only want Mets)           Primary Diagnosis  \
# 0    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 1    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 2    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 3    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 4    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# ..   ...     ...                        ...                         ...
# 239  105       1          Brain Mets Kidney     Squamous cell carcinoma
# 240  492       2          Brain Mets - Lung  Adenocarcinoma of the lung
# 241  246       1           Brain Mets-Lung   Adenocarcinoma of the lung
# 242  257       3      Brain Mets Renal cell        Renal cell carcinoma
# 243  257       3      Brain Mets Renal cell        Renal cell carcinoma
#
#      Age at Diagnosis  Gender  Lesion #       lesion_clinical mri_type  \
# 0                77.0  Female       1.0  1 Lt Inf Cerebellar1   stable
# 1                77.0  Female      10.0  10 Lt Ant Frontal 1    stable
# 2                77.0  Female      11.0       11 Lt Med Ant 1   stable
# 3                77.0  Female      12.0   12 Rt Ant Frontal 1   stable
# 4                77.0  Female      13.0        13 Lt Vertex 1   stable
# ..                ...     ...       ...                   ...      ...
# 239              58.0    Male       1.0           RT Temporal   stable
# 240              73.0    Male      13.0           Rt temporal   stable
# 241              62.0  Female       4.0            Rt Thalmic   stable
# 242              58.0  Female      13.0          Rt Ventricle   stable
# 243              58.0  Female      15.0                Vermis   stable
#
#      duration_tx_to_imag (months)  Fractions  \
# 0                       42.458101        1.0
# 1                       42.458101        1.0
# 2                       42.458101        1.0
# 3                       42.458101        1.0
# 4                       42.458101        1.0
# ..                            ...        ...
# 239                      2.103188        1.0
# 240                     11.501807        1.0
# 241                      0.854420        1.0
# 242                     41.307920        1.0
# 243                     41.307920        1.0
#
#                                 lesion        date          lesion_rtstruct  \
# 0         1 Left Inferior Cerebellar 1  10-31-2013    1 Lt Inf Cerebellar 1
# 1           10 Left Anterior Frontal 1  10-31-2013      10 Lt ant Frontal 1
# 2    11 Left Medial Anterior Frontal 1  10-31-2013  11 Lt med ant frontal 1
# 3          12 Right Anterior Frontal 1  10-31-2013      12 Rt ant frontal 1
# 4                     13 Left Vertex 1  10-31-2013             13 Lt vertex
# ..                                 ...         ...                      ...
# 239                     Right Temporal  09-04-2014              RT Temporal
# 240                     Right Temporal  12-11-2014               R temporal
# 241                     Right Thalamic  07-10-2013          4 Rt Thalamic 1
# 242                    Right Ventricle  09-29-2014             Rt Ventricle
# 243                             Vermis  09-29-2014                   Vermis
#
#         lesion_clean              file_name
# 0    LtInfCerebellar  151_1_LtInfCerebellar
# 1       LtantFrontal     151_1_LtantFrontal
# 2    Ltmedantfrontal  151_1_Ltmedantfrontal
# 3       Rtantfrontal     151_1_Rtantfrontal
# 4           Ltvertex         151_1_Ltvertex
# ..               ...                    ...
# 239       RTTemporal       105_1_RTTemporal
# 240        Rtemporal        492_2_Rtemporal
# 241       RtThalamic       246_1_RtThalamic
# 242      RtVentricle      257_3_RtVentricle
# 243           Vermis           257_3_Vermis
#
# [244 rows x 16 columns]

# %%
rt_lesion_with_age=pd.read_csv('rt_lesions.csv')

# %%
rt_lesion_with_age = rt_lesions.rename(columns={'lesion': 'lesion_rtstruct'})

# %%
rt_lesion_with_age
# Out:
#      sid        date   lesion_rtstruct    lesion_clean  course  \
# 0    103  04-18-2014          R atrium         Ratrium       1
# 1    103  04-18-2014        L temporal       Ltemporal       1
# 2    103  12-18-2014        Rt Frontal       RtFrontal       2
# 3    103  12-18-2014    Rt Sup Frontal    RtSupFrontal       2
# 4    103  12-18-2014  R Inf Cerebellar  RInfCerebellar       2
# ..   ...         ...               ...             ...     ...
# 252  492  12-11-2014  Rt Post parietal  RtPostparietal       2
# 253  492  12-11-2014        Rt frontal       Rtfrontal       2
# 254  492  12-11-2014    R motor cortex    Rmotorcortex       2
# 255  492  12-11-2014       R occipital      Roccipital       2
# 256  492  12-11-2014        R temporal       Rtemporal       2
#
#                 file_name sex  height  weight  age
# 0           103_1_Ratrium   F    1.65      75   78
# 1         103_1_Ltemporal   F    1.65      75   78
# 2         103_2_RtFrontal   F   -1.00      -1   79
# 3      103_2_RtSupFrontal   F   -1.00      -1   79
# 4    103_2_RInfCerebellar   F   -1.00      -1   79
# ..                    ...  ..     ...     ...  ...
# 252  492_2_RtPostparietal   M    1.85      92   72
# 253       492_2_Rtfrontal   M    1.85      92   72
# 254    492_2_Rmotorcortex   M    1.85      92   72
# 255      492_2_Roccipital   M    1.85      92   72
# 256       492_2_Rtemporal   M    1.85      92   72
#
# [257 rows x 10 columns]

# %%
jdfc.merge(rt_lesion_with_age, on=['lesion_rtstruct','sid','course'], how='inner', indicator=True)
# Out:
#      sid  course Diagnosis (Only want Mets)           Primary Diagnosis  \
# 0    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 1    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 2    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 3    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# 4    151       1          Brain Mets -Lung   Adenocarcinoma of the lung
# ..   ...     ...                        ...                         ...
# 239  105       1          Brain Mets Kidney     Squamous cell carcinoma
# 240  492       2          Brain Mets - Lung  Adenocarcinoma of the lung
# 241  246       1           Brain Mets-Lung   Adenocarcinoma of the lung
# 242  257       3      Brain Mets Renal cell        Renal cell carcinoma
# 243  257       3      Brain Mets Renal cell        Renal cell carcinoma
#
#      Age at Diagnosis  Gender  Lesion #       lesion_clinical mri_type  \
# 0                77.0  Female       1.0  1 Lt Inf Cerebellar1   stable
# 1                77.0  Female      10.0  10 Lt Ant Frontal 1    stable
# 2                77.0  Female      11.0       11 Lt Med Ant 1   stable
# 3                77.0  Female      12.0   12 Rt Ant Frontal 1   stable
# 4                77.0  Female      13.0        13 Lt Vertex 1   stable
# ..                ...     ...       ...                   ...      ...
# 239              58.0    Male       1.0           RT Temporal   stable
# 240              73.0    Male      13.0           Rt temporal   stable
# 241              62.0  Female       4.0            Rt Thalmic   stable
# 242              58.0  Female      13.0          Rt Ventricle   stable
# 243              58.0  Female      15.0                Vermis   stable
#
#      duration_tx_to_imag (months)  ...   lesion_clean_x  \
# 0                       42.458101  ...  LtInfCerebellar
# 1                       42.458101  ...     LtantFrontal
# 2                       42.458101  ...  Ltmedantfrontal
# 3                       42.458101  ...     Rtantfrontal
# 4                       42.458101  ...         Ltvertex
# ..                            ...  ...              ...
# 239                      2.103188  ...       RTTemporal
# 240                     11.501807  ...        Rtemporal
# 241                      0.854420  ...       RtThalamic
# 242                     41.307920  ...      RtVentricle
# 243                     41.307920  ...           Vermis
#
#                file_name_x      date_y   lesion_clean_y  \
# 0    151_1_LtInfCerebellar  10-31-2013  LtInfCerebellar
# 1       151_1_LtantFrontal  10-31-2013     LtantFrontal
# 2    151_1_Ltmedantfrontal  10-31-2013  Ltmedantfrontal
# 3       151_1_Rtantfrontal  10-31-2013     Rtantfrontal
# 4           151_1_Ltvertex  10-31-2013         Ltvertex
# ..                     ...         ...              ...
# 239       105_1_RTTemporal  09-04-2014       RTTemporal
# 240        492_2_Rtemporal  12-11-2014        Rtemporal
# 241       246_1_RtThalamic  07-10-2013       RtThalamic
# 242      257_3_RtVentricle  09-29-2014      RtVentricle
# 243           257_3_Vermis  09-29-2014           Vermis
#
#                file_name_y sex height weight age _merge
# 0    151_1_LtInfCerebellar   F   1.69     70  78   both
# 1       151_1_LtantFrontal   F   1.69     70  78   both
# 2    151_1_Ltmedantfrontal   F   1.69     70  78   both
# 3       151_1_Rtantfrontal   F   1.69     70  78   both
# 4           151_1_Ltvertex   F   1.69     70  78   both
# ..                     ...  ..    ...    ...  ..    ...
# 239       105_1_RTTemporal   M   1.78     66  57   both
# 240        492_2_Rtemporal   M   1.85     92  72   both
# 241       246_1_RtThalamic   F   1.60     44  63   both
# 242      257_3_RtVentricle   F   1.70     58  63   both
# 243           257_3_Vermis   F   1.70     58  63   both
#
# [244 rows x 24 columns]

# %%
jdfc.to_csv('connector.csv',index=0)
